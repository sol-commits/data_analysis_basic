# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "date": ["2023-07-01", "2023-07-01", "2023-07-01", "2023-07-01", "2023-07-01"],
    "category1": ["메인", "메인", "사이드", "음료", "사이드"],
    "category2": ["양념치킨", "간장치킨", "치즈볼", "콜라", "감자튀김"],
    "count": [1, 2, 1, 4, 1],
    "price": [20000, 50000, 6000, 8000, 8000]
})

# %%
df
# Out:
#          date category1 category2  count  price
# 0  2023-07-01        메인      양념치킨      1  20000
# 1  2023-07-01        메인      간장치킨      2  50000
# 2  2023-07-01       사이드       치즈볼      1   6000
# 3  2023-07-01        음료        콜라      4   8000
# 4  2023-07-01       사이드      감자튀김      1   8000

# %% [markdown]
# # pd.pivot()

# %%
# date와 category2만 뽑아서 판매수량 표시
df.pivot(index='date', columns='category2', values='count')
# Out:
# category2   간장치킨  감자튀김  양념치킨  치즈볼  콜라
# date
# 2023-07-01     2     1     1    1   4

# %%
# category2와 7월 1일의 판매가격
df.pivot(index='category2', columns='date', values='price')
# Out:
# date       2023-07-01
# category2
# 간장치킨            50000
# 감자튀김             8000
# 양념치킨            20000
# 치즈볼              6000
# 콜라               8000

# %%
df.pivot(index='category1', columns='category2', values=['count', 'price']).fillna(0)
# Out:
#           count                        price
# category2  간장치킨 감자튀김 양념치킨  치즈볼   콜라     간장치킨    감자튀김     양념치킨     치즈볼      콜라
# category1
# 메인          2.0  0.0  1.0  0.0  0.0  50000.0     0.0  20000.0     0.0     0.0
# 사이드         0.0  1.0  0.0  1.0  0.0      0.0  8000.0      0.0  6000.0     0.0
# 음료          0.0  0.0  0.0  0.0  4.0      0.0     0.0      0.0     0.0  8000.0

# %%
''' ValueError: Index contains duplicate entries, cannot reshape
df.pivot(index='date', columns='category1', values='price')
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.pivot(index='date', columns='category1', values='price')
#
# File /usr/local/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File /usr/local/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:557, in pivot(data, columns, index, values)
#     553         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     554 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     555 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     556 # "Hashable"
# --> 557 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     558 result.index.names = [
#     559     name if name is not lib.NoDefault else None for name in result.index.names
#     560 ]
#     562 return result
#
# File /usr/local/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/series.py:4313, in Series.unstack(self, level, fill_value)
#    4270 """
#    4271 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4272
#    (...)
#    4309 b    2    4
#    4310 """
#    4311 from pandas.core.reshape.reshape import unstack
# -> 4313 return unstack(self, level, fill_value)
#
# File /usr/local/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/reshape.py:488, in unstack(obj, level, fill_value)
#     486 if is_1d_only_ea_dtype(obj.dtype):
#     487     return _unstack_extension_series(obj, level, fill_value)
# --> 488 unstacker = _Unstacker(
#     489     obj.index, level=level, constructor=obj._constructor_expanddim
#     490 )
#     491 return unstacker.get_result(
#     492     obj._values, value_columns=None, fill_value=fill_value
#     493 )
#
# File /usr/local/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/reshape.py:136, in _Unstacker.__init__(self, index, level, constructor)
#     128 if num_cells > np.iinfo(np.int32).max:
#     129     warnings.warn(
#     130         f"The following operation may generate {num_cells} cells "
#     131         f"in the resulting pandas object.",
#     132         PerformanceWarning,
#     133         stacklevel=find_stack_level(),
#     134     )
# --> 136 self._make_selectors()
#
# File /usr/local/anaconda3/envs/ds_study/lib/python3.8/site-packages/pandas/core/reshape/reshape.py:188, in _Unstacker._make_selectors(self)
#     185 mask.put(selector, True)
#     187 if mask.sum() < len(self.index):
# --> 188     raise ValueError("Index contains duplicate entries, cannot reshape")
#     190 self.group_index = comp_index
#     191 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# - `pd.pivot()`은 집계하는 능력이 없고, `pd.pivot_table()`은 집계할 수 있음

# %% [markdown]
# # pd.pivot_table()

# %%
df.pivot_table(index='date', columns='category1', values='price')
# Out:
# category1      메인   사이드    음료
# date
# 2023-07-01  35000  7000  8000

# %%
# 일별 총 판매수량과 총 판매금액
df.pivot_table(index='date', values=['count', 'price'], aggfunc='sum')
# Out:
#             count  price
# date
# 2023-07-01      9  92000

# %%
# 일별 총 판매수량과 평균 판매금액
df.pivot_table(index='date', 
               values=['count', 'price'],
               aggfunc={'count': 'sum', 'price': 'mean'})
# Out:
#             count  price
# date
# 2023-07-01      9  18400

# %% [markdown]
# # pd.melt()

# %%
df2 = pd.DataFrame({
    "category1" : ["메인", "메인", "메인", "메인", "메인"] ,
    "category2" : ["양념치킨", "간장치킨", "반반", "마늘치킨", "후라이드"],
    "2023-07-01" : [10, 26, 11, 5, 10] ,
    "2023-07-02" : [20, 5, 20, 5, 30] ,
    "2023-07-03" : [10, 25, 12, 12, 30] ,
    "2023-07-04" : [5, 15, 5, 25, 5] ,
    "2023-07-05" : [30, 10, 21, 22, 10] 
})

# %%
df2
# Out:
#   category1 category2  2023-07-01  2023-07-02  2023-07-03  2023-07-04  \
# 0        메인      양념치킨          10          20          10           5
# 1        메인      간장치킨          26           5          25          15
# 2        메인        반반          11          20          12           5
# 3        메인      마늘치킨           5           5          12          25
# 4        메인      후라이드          10          30          30           5
#
#    2023-07-05
# 0          30
# 1          10
# 2          21
# 3          22
# 4          10

# %%
df2.melt(id_vars=["category1", "category2"])
# Out:
#    category1 category2    variable  value
# 0         메인      양념치킨  2023-07-01     10
# 1         메인      간장치킨  2023-07-01     26
# 2         메인        반반  2023-07-01     11
# 3         메인      마늘치킨  2023-07-01      5
# 4         메인      후라이드  2023-07-01     10
# 5         메인      양념치킨  2023-07-02     20
# 6         메인      간장치킨  2023-07-02      5
# 7         메인        반반  2023-07-02     20
# 8         메인      마늘치킨  2023-07-02      5
# 9         메인      후라이드  2023-07-02     30
# 10        메인      양념치킨  2023-07-03     10
# 11        메인      간장치킨  2023-07-03     25
# 12        메인        반반  2023-07-03     12
# 13        메인      마늘치킨  2023-07-03     12
# 14        메인      후라이드  2023-07-03     30
# 15        메인      양념치킨  2023-07-04      5
# 16        메인      간장치킨  2023-07-04     15
# 17        메인        반반  2023-07-04      5
# 18        메인      마늘치킨  2023-07-04     25
# 19        메인      후라이드  2023-07-04      5
# 20        메인      양념치킨  2023-07-05     30
# 21        메인      간장치킨  2023-07-05     10
# 22        메인        반반  2023-07-05     21
# 23        메인      마늘치킨  2023-07-05     22
# 24        메인      후라이드  2023-07-05     10

# %%
df2.melt(id_vars=["category1", "category2"], var_name='date', value_name='cnt')
# Out:
#    category1 category2        date  cnt
# 0         메인      양념치킨  2023-07-01   10
# 1         메인      간장치킨  2023-07-01   26
# 2         메인        반반  2023-07-01   11
# 3         메인      마늘치킨  2023-07-01    5
# 4         메인      후라이드  2023-07-01   10
# 5         메인      양념치킨  2023-07-02   20
# 6         메인      간장치킨  2023-07-02    5
# 7         메인        반반  2023-07-02   20
# 8         메인      마늘치킨  2023-07-02    5
# 9         메인      후라이드  2023-07-02   30
# 10        메인      양념치킨  2023-07-03   10
# 11        메인      간장치킨  2023-07-03   25
# 12        메인        반반  2023-07-03   12
# 13        메인      마늘치킨  2023-07-03   12
# 14        메인      후라이드  2023-07-03   30
# 15        메인      양념치킨  2023-07-04    5
# 16        메인      간장치킨  2023-07-04   15
# 17        메인        반반  2023-07-04    5
# 18        메인      마늘치킨  2023-07-04   25
# 19        메인      후라이드  2023-07-04    5
# 20        메인      양념치킨  2023-07-05   30
# 21        메인      간장치킨  2023-07-05   10
# 22        메인        반반  2023-07-05   21
# 23        메인      마늘치킨  2023-07-05   22
# 24        메인      후라이드  2023-07-05   10

# %%
tmp = df2.melt(id_vars=["category1", "category2"], var_name='date', value_name='cnt')
tmp.head()
# Out:
#   category1 category2        date  cnt
# 0        메인      양념치킨  2023-07-01   10
# 1        메인      간장치킨  2023-07-01   26
# 2        메인        반반  2023-07-01   11
# 3        메인      마늘치킨  2023-07-01    5
# 4        메인      후라이드  2023-07-01   10

# %%
tmp.pivot_table(index=['category1', 'category2'], values='cnt')
# Out:
#                       cnt
# category1 category2
# 메인        간장치킨       16.2
#           마늘치킨       13.8
#           반반         13.8
#           양념치킨       15.0
#           후라이드       17.0

# %% [markdown]
# # pd.concat()
#
# 데이터프레임을 결합

# %%
sales_day1 = pd.DataFrame(
        {"date" : ["2023-07-01","2023-07-01", "2023-07-01", "2023-07-01", "2023-07-01"] ,
        "category1" : ["메인", "메인", "사이드", "음료", "사이드"] ,
        "category2" : ["양념치킨", "간장치킨", "치즈볼", "콜라", "감자튀김"],
        "count" : [1, 2, 1, 4, 1], 
        "price" : [20000, 50000, 6000, 8000, 8000]})

# %%
sales_day2 = pd.DataFrame(
        {"date" : ["2023-07-02","2023-07-02", "2023-07-02", "2023-07-02", "2023-07-02"] ,
        "category1" : ["사이드", "메인", "메인", "음료", "메인"] ,
        "category2" : ["국물떡볶이", "간장치킨", "후라이드", "제로콜라", "양념치킨"],
        "count" : [1, 3, 1, 3, 2], 
        "price" : [10000, 75000, 18000, 9000, 40000]})

# %%
sales_day3 = pd.DataFrame(
        {"date" : ["2023-07-03","2023-07-03", "2023-07-03", "2023-07-03"] ,
        "category1" : ["사이드", "메인", "메인", "음료"] ,
        "category2" : ["국물떡볶이", "간장치킨", "후라이드", "제로콜라"],
        "count" : [1, 3, 1, 3], 
        "price" : [10000, 75000, 18000, 9000]})

# %%
sales_day4 = pd.DataFrame(
        {"date" : ["2023-07-03","2023-07-03", "2023-07-03", "2023-07-03"] ,
        "category1" : ["사이드", "메인", "메인", "음료"] ,
        "category2" : ["국물떡볶이", "간장치킨", "후라이드", "제로콜라"],
        "count" : [1, 3, 1, 3], 
        "가격" : [10000, 75000, 18000, 9000]})

# %%
pd.concat([sales_day1, sales_day2])
# Out:
#          date category1 category2  count  price
# 0  2023-07-01        메인      양념치킨      1  20000
# 1  2023-07-01        메인      간장치킨      2  50000
# 2  2023-07-01       사이드       치즈볼      1   6000
# 3  2023-07-01        음료        콜라      4   8000
# 4  2023-07-01       사이드      감자튀김      1   8000
# 0  2023-07-02       사이드     국물떡볶이      1  10000
# 1  2023-07-02        메인      간장치킨      3  75000
# 2  2023-07-02        메인      후라이드      1  18000
# 3  2023-07-02        음료      제로콜라      3   9000
# 4  2023-07-02        메인      양념치킨      2  40000

# %%
pd.concat([sales_day1, sales_day2], axis=1)
# Out:
#          date category1 category2  count  price        date category1  \
# 0  2023-07-01        메인      양념치킨      1  20000  2023-07-02       사이드
# 1  2023-07-01        메인      간장치킨      2  50000  2023-07-02        메인
# 2  2023-07-01       사이드       치즈볼      1   6000  2023-07-02        메인
# 3  2023-07-01        음료        콜라      4   8000  2023-07-02        음료
# 4  2023-07-01       사이드      감자튀김      1   8000  2023-07-02        메인
#
#   category2  count  price
# 0     국물떡볶이      1  10000
# 1      간장치킨      3  75000
# 2      후라이드      1  18000
# 3      제로콜라      3   9000
# 4      양념치킨      2  40000

# %%
# row 개수가 다른 데이터프레임끼리 합칠 경우
pd.concat([sales_day1, sales_day3], axis=1)
# Out:
#          date category1 category2  count  price        date category1  \
# 0  2023-07-01        메인      양념치킨      1  20000  2023-07-03       사이드
# 1  2023-07-01        메인      간장치킨      2  50000  2023-07-03        메인
# 2  2023-07-01       사이드       치즈볼      1   6000  2023-07-03        메인
# 3  2023-07-01        음료        콜라      4   8000  2023-07-03        음료
# 4  2023-07-01       사이드      감자튀김      1   8000         NaN       NaN
#
#   category2  count    price
# 0     국물떡볶이    1.0  10000.0
# 1      간장치킨    3.0  75000.0
# 2      후라이드    1.0  18000.0
# 3      제로콜라    3.0   9000.0
# 4       NaN    NaN      NaN

# %%
# 컬럼명이 다른 데이터프레임끼리 합칠 경우
pd.concat([sales_day1, sales_day4], axis=0)
# Out:
#          date category1 category2  count    price       가격
# 0  2023-07-01        메인      양념치킨      1  20000.0      NaN
# 1  2023-07-01        메인      간장치킨      2  50000.0      NaN
# 2  2023-07-01       사이드       치즈볼      1   6000.0      NaN
# 3  2023-07-01        음료        콜라      4   8000.0      NaN
# 4  2023-07-01       사이드      감자튀김      1   8000.0      NaN
# 0  2023-07-03       사이드     국물떡볶이      1      NaN  10000.0
# 1  2023-07-03        메인      간장치킨      3      NaN  75000.0
# 2  2023-07-03        메인      후라이드      1      NaN  18000.0
# 3  2023-07-03        음료      제로콜라      3      NaN   9000.0
